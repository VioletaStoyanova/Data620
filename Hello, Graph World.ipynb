# %%
# importing required packages for this project

import matplotlib.pyplot as plt
import networkx as nx

# %%
# let's create a graph in which we can work on. Since we have not put any nodes yet there is an empty graph 
Graph = nx.Graph()

# %% [raw]
# # Since we know that there are 10 people, according to the krackhardt_kite_graph there will be 18 edges for 10 nodes.
# # from A to J, we have 10 names
#
# nodes = ['Andre','Beverly', 'Carol', 'Diane', 'Ed', 'Fernando','Garth','Heather','Ike', 'Jane']
#
# Graph.add_nodes_from(nodes)
#
# # to check if the number of nodes are correct
# Graph.number_of_nodes()

# %%
# now let's add the edges, there are 18 connections
edges = [('Andre', 'Beverly'), ('Andre', 'Carol'), ('Andre', 'Diane'), ('Andre', 'Fernando'),
         ('Beverly', 'Diane'), ('Beverly', 'Ed'), ('Beverly', 'Garth'),
         ('Carol', 'Diane'), ('Carol', 'Fernando'),
         ('Diane', 'Ed'), ('Diane', 'Fernando'), ('Diane', 'Garth'),
         ('Ed', 'Garth'),
         ('Fernando', 'Garth'),
         ('Fernando', 'Heather'),
         ('Garth', 'Heather'),
         ('Heather', 'Ike'),
         ('Ike', 'Jane'),]

Graph.add_edges_from(edges)

# to check if the number of edges are correct
Graph.number_of_edges()
# Out:
# 18

# %%
# to check the degree of the graph
nx.degree(Graph)
# Out:
# DegreeView({'Andre': 4, 'Beverly': 4, 'Carol': 3, 'Diane': 6, 'Fernando': 5, 'Ed': 3, 'Garth': 5, 'Heather': 3, 'Ike': 2, 'Jane': 1})

# %%
# Degree centrality
d=nx.degree_centrality(Graph) 
print(d)
# Out:
# {'Andre': 0.4444444444444444, 'Beverly': 0.4444444444444444, 'Carol': 0.3333333333333333, 'Diane': 0.6666666666666666, 'Fernando': 0.5555555555555556, 'Ed': 0.3333333333333333, 'Garth': 0.5555555555555556, 'Heather': 0.3333333333333333, 'Ike': 0.2222222222222222, 'Jane': 0.1111111111111111}

# %%
#Betweenness Centrality 
b=nx.betweenness_centrality(Graph) 
print(b)
# Out:
# {'Andre': 0.023148148148148143, 'Beverly': 0.023148148148148143, 'Carol': 0.0, 'Diane': 0.10185185185185185, 'Fernando': 0.23148148148148148, 'Ed': 0.0, 'Garth': 0.23148148148148148, 'Heather': 0.38888888888888884, 'Ike': 0.2222222222222222, 'Jane': 0.0}

# %%
# now let's plot the graph
nx.draw(Graph, labels=None,font_size=14, font_color='g',font_family='times new roman')
plt.title('Hello, Graph World', size=22, color='m')

plt.show()

# %%
# Out:
# {'Andre': 0.4444444444444444, 'Beverly': 0.4444444444444444, 'Carol': 0.3333333333333333, 'Diane': 0.6666666666666666, 'Fernando': 0.5555555555555556, 'Ed': 0.3333333333333333, 'Garth': 0.5555555555555556, 'Heather': 0.3333333333333333, 'Ike': 0.2222222222222222, 'Jane': 0.1111111111111111}
